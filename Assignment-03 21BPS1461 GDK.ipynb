# %% [markdown]
# # Name:G.Dheekshith Kumar
# # Reg No:21BPS1461
# # Assignment : 03
# ## Mail Id:dheekshithkumar.g2021@vitstudent.ac.in

# %% [markdown]
# ### Task-1&2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\ADMIN\\Downloads\\penguins_size.csv")
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.shape
# Out:
# (344, 7)

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df['species'].nunique()
# Out:
# 3

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# ### Task-3
# ### Univariate

# %%
plt.figure(figsize=(8, 6))
sns.distplot(df['culmen_length_mm'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\1605283660.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['culmen_length_mm'])
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.displot(df.species)

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['island'])
plt.title('Island')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.pie((df['sex']).value_counts(),[0,0,0.2],labels = ['male','female','Null'],autopct ='%1.1f%%',shadow = False,colors = ['purple','yellow','orange'],)
plt.title('Number of views')
plt.show()

# %% [markdown]
# ### Bivariate

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x = df['culmen_length_mm'],y=df['flipper_length_mm'])
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='flipper_length_mm'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x = df['culmen_length_mm'],y=df['flipper_length_mm'])
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# ### Multi-Variate

# %%
#pairplot
penguins = sns.load_dataset("penguins")
sns.pairplot(penguins, hue="species")

# Show the plot
plt.show()

# %%
#heatmap
sns.heatmap(df.corr())
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\1087955420.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
from matplotlib import rcParams
rcParams['figure.figsize']=8,6
sns.heatmap(df.corr(),annot=True,annot_kws={"size": 14})
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\3782732391.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,annot_kws={"size": 14})
# <Axes: >

# %% [markdown]
# ### Task-4

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ### Task-5

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
df['sex'] = df['sex'].replace(".","MALE")

# %%
df.sex.value_counts()
# Out:
# MALE      169
# FEMALE    165
# Name: sex, dtype: int64

# %%
df['sex'] = df['sex'].fillna("MALE")

# %%
df.island.value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
df.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                  False
# dtype: bool

# %%
df.median()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# culmen_length_mm       44.45
# culmen_depth_mm        17.30
# flipper_length_mm     197.00
# body_mass_g          4050.00
# dtype: float64

# %%
df = df.fillna(df.median())
df.isnull().sum()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\1273592041.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(df.median())
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Task-6

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0    MALE
# 4       3450.0  FEMALE

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %% [markdown]
# ### Task-7

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235000           0.655858
# culmen_depth_mm           -0.235000         1.000000          -0.583832
# flipper_length_mm          0.655858        -0.583832           1.000000
# body_mass_g                0.594925        -0.471942           0.871221
#
#                    body_mass_g
# culmen_length_mm      0.594925
# culmen_depth_mm      -0.471942
# flipper_length_mm     0.871221
# body_mass_g           1.000000

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])
df['species'].unique()
# Out:
# array([0, 1, 2])

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     species  culmen_length_mm  culmen_depth_mm  \
# species            1.000000          0.728706        -0.741282
# culmen_length_mm   0.728706          1.000000        -0.235000
# culmen_depth_mm   -0.741282         -0.235000         1.000000
# flipper_length_mm  0.850819          0.655858        -0.583832
# body_mass_g        0.747547          0.594925        -0.471942
#
#                    flipper_length_mm  body_mass_g
# species                     0.850819     0.747547
# culmen_length_mm            0.655858     0.594925
# culmen_depth_mm            -0.583832    -0.471942
# flipper_length_mm           1.000000     0.871221
# ...

# %%
corr_mat = df.corr()
corr_mat['species'].sort_values(ascending=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2592\3744662350.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_mat = df.corr()
# species              1.000000
# flipper_length_mm    0.850819
# body_mass_g          0.747547
# culmen_length_mm     0.728706
# culmen_depth_mm     -0.741282
# Name: species, dtype: float64

# %%
corr_mat.head()
# Out:
#                     species  culmen_length_mm  culmen_depth_mm  \
# species            1.000000          0.728706        -0.741282
# culmen_length_mm   0.728706          1.000000        -0.235000
# culmen_depth_mm   -0.741282         -0.235000         1.000000
# flipper_length_mm  0.850819          0.655858        -0.583832
# body_mass_g        0.747547          0.594925        -0.471942
#
#                    flipper_length_mm  body_mass_g
# species                     0.850819     0.747547
# culmen_length_mm            0.655858     0.594925
# culmen_depth_mm            -0.583832    -0.471942
# flipper_length_mm           1.000000     0.871221
# body_mass_g                 0.871221     1.000000

# %% [markdown]
# ### Task-8

# %%
df.sex = le.fit_transform(df.sex)
df.island = le.fit_transform(df.island)
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    1
# 1       3800.0    0
# 2       3250.0    0
# 3       4050.0    1
# 4       3450.0    0

# %%
#one hot labedencoding
data = pd.get_dummies(df, columns=['sex'])
data.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex_0  sex_1
# 0       3750.0      0      1
# 1       3800.0      1      0
# 2       3250.0      1      0
# 3       4050.0      0      1
# 4       3450.0      1      0

# %% [markdown]
# ### Task-9

# %%
y = data['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int32

# %%
X = data.drop(columns=['species'],axis=1)
X.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2             39.10             18.7              181.0       3750.0
# 1       2             39.50             17.4              186.0       3800.0
# 2       2             40.30             18.0              195.0       3250.0
# 3       2             44.45             17.3              197.0       4050.0
# 4       2             36.70             19.3              193.0       3450.0
#
#    sex_0  sex_1
# 0      0      1
# 1      1      0
# 2      1      0
# 3      0      1
# 4      1      0

# %% [markdown]
# ### Task-10

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
X = df.iloc[:, 1:]
X_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)
X_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  0.0

# %% [markdown]
# ### Task-11

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 219     0.5          0.658182         0.666667           0.440678
# 271     0.0          0.596364         0.119048           0.813559
# 266     0.0          0.487273         0.095238           0.644068
# 335     0.0          0.836364         0.345238           0.983051
# 217     0.5          0.636364         0.607143           0.355932
# ..      ...               ...              ...                ...
# 323     0.0          0.618182         0.226190           0.949153
# 192     0.5          0.614545         0.761905           0.644068
# 117     1.0          0.189091         0.880952           0.457627
# 47      0.5          0.196364         0.690476           0.118644
# 172     0.5          0.374545         0.500000           0.152542
#
#      body_mass_g  sex
# 219     0.298611  0.0
# 271     0.722222  1.0
# 266     0.416667  0.0
# 335     0.875000  1.0
# 217     0.298611  1.0
# ..           ...  ...
# ...

# %%
X_test
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 141     0.5          0.309091         0.488095           0.254237
# 6       1.0          0.247273         0.559524           0.152542
# 60      0.0          0.130909         0.452381           0.220339
# 249     0.0          0.650909         0.261905           0.813559
# 54      0.0          0.087273         0.595238           0.254237
# ..      ...               ...              ...                ...
# 81      1.0          0.392727         0.535714           0.406780
# 1       1.0          0.269091         0.511905           0.237288
# 120     1.0          0.149091         0.488095           0.254237
# 8       1.0          0.072727         0.595238           0.355932
# 313     0.0          0.632727         0.357143           0.881356
#
#      body_mass_g  sex
# 141     0.215278  1.0
# 6       0.256944  0.0
# 60      0.125000  0.0
# 249     0.791667  1.0
# 54      0.055556  0.0
# ..           ...  ...
# ...

# %%
y_test
# Out:
# 141    0
# 6      0
# 60     0
# 249    2
# 54     0
#       ..
# 81     0
# 1      0
# 120    0
# 8      0
# 313    2
# Name: species, Length: 104, dtype: int32

# %%
y_train
# Out:
# 219    1
# 271    2
# 266    2
# 335    2
# 217    1
#       ..
# 323    2
# 192    1
# 117    0
# 47     0
# 172    1
# Name: species, Length: 240, dtype: int32

# %% [markdown]
# ### Task-12

# %%
X_train.shape
# Out:
# (240, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
X_test.shape
# Out:
# (104, 6)

# %%
y_test.shape
# Out:
# (104,)
